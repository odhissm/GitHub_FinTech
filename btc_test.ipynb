# %% [markdown]
# <a href="https://colab.research.google.com/github/odhissm/GitHub_FinTech/blob/main/btc_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the required libraries
from IPython.display import clear_output
try:
  #!pip install pystan
  # !pip install pytrends
  # !pip install yfinance
  # !pip install yahoofinancials
except:
  print("Error installing libraries")
finally:
  clear_output()
  print('Libraries successfully installed')
# Out:
# Libraries successfully installed

# %%
# Imports
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from pathlib import Path
import yfinance as yf


#import yfinance as yf
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
from pytrends.request import TrendReq

# %% [markdown]
# PrePare the data to be used

# %%
#pytrends = TrendReq(hl=’en-US’, tz=360)
pytrends = TrendReq()

# %%
pytrends.build_payload(kw_list=['bitcoin', 'crypto', 'cryptocurrency', 'btc', 'BlockChain'], timeframe='2017-01-01 2022-01-12')

# Interest

df = pytrends.interest_over_time().rename_axis('Date')

df
# Out:
#             bitcoin  crypto  cryptocurrency  btc  BlockChain isPartial
# Date
# 2017-01-01        6       0               0    2           1     False
# 2017-01-08        5       0               0    2           1     False
# 2017-01-15        4       0               0    1           1     False
# 2017-01-22        4       0               0    1           1     False
# 2017-01-29        4       0               0    1           1     False
# ...             ...     ...             ...  ...         ...       ...
# 2021-12-12       23      12               3    6           2     False
# 2021-12-19       20      12               2    6           2     False
# 2021-12-26       20      13               2    6           2     False
# 2022-01-02       25      15               3    7           2     False
# 2022-01-09       27      13               3    7           2      True
#
# [263 rows x 6 columns]

# %%
btc = yf.Ticker("BTC-USD")

# get historical market data
btc_usd_df = btc.history(
                          start='2017-01-01', 
                      end='2022-01-12', 
                      progress=False,
)


btc_usd_df
# Out:
#                     Open          High  ...  Dividends  Stock Splits
# Date                                    ...
# 2017-01-01    963.658020   1003.080017  ...          0             0
# 2017-01-02    998.617004   1031.390015  ...          0             0
# 2017-01-03   1021.599976   1044.079956  ...          0             0
# 2017-01-04   1044.400024   1159.420044  ...          0             0
# 2017-01-05   1156.729980   1191.099976  ...          0             0
# ...                  ...           ...  ...        ...           ...
# 2022-01-08  41561.464844  42228.941406  ...          0             0
# 2022-01-09  41734.726562  42663.949219  ...          0             0
# 2022-01-10  41910.230469  42199.484375  ...          0             0
# 2022-01-11  41819.507812  43001.156250  ...          0             0
# 2022-01-12  42742.179688  44135.367188  ...          0             0
#
# [1838 rows x 7 columns]

# %%
dates_df = pd.DataFrame(
    {'Date':pd.date_range('2017-01-01', '2022-01-12')}
)


dates_df['holiday'] = dates_df['Date']

dates_df = dates_df.set_index('Date')
dates_df
# Out:
#               holiday
# Date
# 2017-01-01 2017-01-01
# 2017-01-02 2017-01-02
# 2017-01-03 2017-01-03
# 2017-01-04 2017-01-04
# 2017-01-05 2017-01-05
# ...               ...
# 2022-01-08 2022-01-08
# 2022-01-09 2022-01-09
# 2022-01-10 2022-01-10
# 2022-01-11 2022-01-11
# 2022-01-12 2022-01-12
#
# [1838 rows x 1 columns]

# %%
cal = calendar()

holidays = cal.holidays(
    start=dates_df['holiday'].min(),
    end=dates_df['holiday'].max()
)

holidays
# Out:
# DatetimeIndex(['2017-01-02', '2017-01-16', '2017-02-20', '2017-05-29',
#                '2017-07-04', '2017-09-04', '2017-10-09', '2017-11-10',
#                '2017-11-23', '2017-12-25', '2018-01-01', '2018-01-15',
#                '2018-02-19', '2018-05-28', '2018-07-04', '2018-09-03',
#                '2018-10-08', '2018-11-12', '2018-11-22', '2018-12-25',
#                '2019-01-01', '2019-01-21', '2019-02-18', '2019-05-27',
#                '2019-07-04', '2019-09-02', '2019-10-14', '2019-11-11',
#                '2019-11-28', '2019-12-25', '2020-01-01', '2020-01-20',
#                '2020-02-17', '2020-05-25', '2020-07-03', '2020-09-07',
#                '2020-10-12', '2020-11-11', '2020-11-26', '2020-12-25',
#                '2021-01-01', '2021-01-18', '2021-02-15', '2021-05-31',
#                '2021-07-05', '2021-09-06', '2021-10-11', '2021-11-11',
#                '2021-11-25', '2021-12-24', '2021-12-31'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates_df['holiday'] = dates_df['holiday'].isin(holidays).astype(int) 
dates_df
# Out:
#             holiday
# Date
# 2017-01-01        0
# 2017-01-02        1
# 2017-01-03        0
# 2017-01-04        0
# 2017-01-05        0
# ...             ...
# 2022-01-08        0
# 2022-01-09        0
# 2022-01-10        0
# 2022-01-11        0
# 2022-01-12        0
#
# [1838 rows x 1 columns]

# %%
btc_usd_df_01 = pd.concat ([btc_usd_df , dates_df, df], axis=1).fillna(0)



btc_usd_df_01['isPartial'] = np.where((btc_usd_df_01.isPartial == 'False'), 0, btc_usd_df_01.isPartial)
btc_usd_df_01['isPartial'] = np.where((btc_usd_df_01.isPartial == 'True'), 1, btc_usd_df_01.isPartial)


btc_usd_df_01
# Out:
#                     Open          High           Low  ...  btc  BlockChain  isPartial
# Date                                                  ...
# 2017-01-01    963.658020   1003.080017    958.698975  ...  2.0         1.0          0
# 2017-01-02    998.617004   1031.390015    996.702026  ...  0.0         0.0          0
# 2017-01-03   1021.599976   1044.079956   1021.599976  ...  0.0         0.0          0
# 2017-01-04   1044.400024   1159.420044   1044.400024  ...  0.0         0.0          0
# 2017-01-05   1156.729980   1191.099976    910.416992  ...  0.0         0.0          0
# ...                  ...           ...           ...  ...  ...         ...        ...
# 2022-01-08  41561.464844  42228.941406  40672.277344  ...  0.0         0.0          0
# 2022-01-09  41734.726562  42663.949219  41338.160156  ...  7.0         2.0          1
# 2022-01-10  41910.230469  42199.484375  39796.570312  ...  0.0         0.0          0
# ...

# %%
def train_test_split(btc_usd_df_01, test_size=0.2):
    split_row = len(btc_usd_df_01) - int(test_size * len(btc_usd_df_01))
    train_data = btc_usd_df_01.iloc[:split_row]
    test_data = btc_usd_df_01.iloc[split_row:]
    return train_data, test_data
train, test = train_test_split(hist, test_size=0.2)
